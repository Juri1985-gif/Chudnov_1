# %%
import pandas as pd

# %%
host = 'hh-pgsql-public.ebi.ac.uk'
port = 5432
database = 'pfmegrnargs'
user = 'reader'
password = 'NWDMCE5xdipIjRrp'

# %%
import psycopg2

# %%
try:
    conn = psycopg2.connect(dbname=database, user=user, password=password, host=host)
except:
    print('Can`t establish connection to database')

# %%
with conn.cursor() as cursor:
    cursor.execute('SELECT * FROM rnc_database limit 10')
    rnc_database_10 = cursor.fetchall()

# %%
rnc_database_10 [:10]
# Out:
# [(21,
#   datetime.datetime(2017, 5, 2, 0, 0),
#   'RNACEN',
#   'NONCODE',
#   146,
#   'NONCODE',
#   'Y',
#   ' ',
#   'NONCODE',
#   '',
#   1130,
#   201,
#   244296,
#   234669,
#   7,
#   'is an integrated knowledge database dedicated to non-coding RNAs',
#   'http://www.noncode.org/',
#   [{'upi': 'URS000019B796', 'taxid': 9606},
#    {'upi': 'URS00008189E4', 'taxid': 9606},
#    {'upi': 'URS000058E3EB', 'taxid': 9606}],
#   [{'title': 'NONCODE 2016: an informative and valuable data source of long non-coding RNAs',
#     'authors': 'Zhao Y, Li H, Fang S, Kang Y, Wu W, Hao Y, Li Z, Bu D, Sun N, Zhang MQ, Chen R',
#     'journal': 'Nucleic Acids Res. 2016 Jan 4;44(D1):D203-8',
#     'pubmed_id': '26586799'}]),
#  (5,
#   datetime.datetime(2017, 5, 17, 0, 0),
#   'RNACEN',
#   'VEGA',
#   98,
#   'VEGA',
#   'N',
#   ' ',
#   'VEGA',
#   'PRJEB4568',
#   None,
#   None,
#   None,
#   0,
#   0,
# ...

# %%
rnc_database_df = pd.DataFrame(rnc_database_10)
rnc_database_df.head(10)
# Out:
#    0          1       2          3    4          5  6  7          8   \
# 0  21 2017-05-02  RNACEN    NONCODE  146    NONCODE  Y       NONCODE
# 1   5 2017-05-17  RNACEN       VEGA   98       VEGA  N          VEGA
# 2  26 2017-05-01  RNACEN    GENCODE  450    GENCODE  N       GENCODE
# 3   1 2017-05-01  RNACEN        ENA  968        ENA  Y           ENA
# 4  14 2017-05-01  RNACEN       TAIR  982       TAIR  Y          TAIR
# 5   9 2017-05-01  RNACEN     REFSEQ  969     RefSeq  Y        RefSeq
# 6  41 2017-05-01  RNACEN  GENECARDS  978  MalaCards  Y     GeneCards
# 7  10 2017-05-01  RNACEN        RDP   85        RDP  Y           RDP
# 8  20 2017-05-01  RNACEN  LNCIPEDIA  935  LNCipedia  Y     LNCipedia
# 9  15 2017-05-02  RNACEN   WORMBASE  970   WormBase  Y      WormBase
#
#            9       10      11        12        13      14  \
# 0              1130.0   201.0  244296.0    234669       7
# 1   PRJEB4568     NaN     NaN       NaN         0       0
# ...

# %%
with conn.cursor() as cursor:
    cursor.execute('SELECT display_name, num_sequences, num_organisms, url FROM rnc_database limit 10')
    rnc_database_1 = cursor.fetchall()

# %%
rnc_database_1 [:10]
# Out:
# [('NONCODE', 234669, 7, 'http://www.noncode.org/'),
#  ('VEGA', 0, 0, 'http://vega.sanger.ac.uk/'),
#  ('GENCODE', 47677, 2, 'http://gencodegenes.org/'),
#  ('ENA', 12086180, 814855, 'https://www.ebi.ac.uk/ena/browser/'),
#  ('TAIR', 4406, 1, 'http://www.arabidopsis.org/'),
#  ('RefSeq', 120355, 22524, 'http://www.ncbi.nlm.nih.gov/refseq/'),
#  ('GeneCards', 425357, 1, 'https://www.genecards.org/'),
#  ('RDP', 4779, 2487, 'http://rdp.cme.msu.edu/'),
#  ('LNCipedia', 126876, 1, 'http://www.lncipedia.org/'),
#  ('WormBase', 25550, 1, 'http://www.wormbase.org/')]

# %%
rnc_database_1_df = pd.DataFrame(rnc_database_1)
rnc_database_1_df.head(10)
# Out:
#            0         1       2                                    3
# 0    NONCODE    234669       7              http://www.noncode.org/
# 1       VEGA         0       0            http://vega.sanger.ac.uk/
# 2    GENCODE     47677       2             http://gencodegenes.org/
# 3        ENA  12086180  814855   https://www.ebi.ac.uk/ena/browser/
# 4       TAIR      4406       1          http://www.arabidopsis.org/
# 5     RefSeq    120355   22524  http://www.ncbi.nlm.nih.gov/refseq/
# 6  GeneCards    425357       1           https://www.genecards.org/
# 7        RDP      4779    2487              http://rdp.cme.msu.edu/
# 8  LNCipedia    126876       1            http://www.lncipedia.org/
# 9   WormBase     25550       1             http://www.wormbase.org/
